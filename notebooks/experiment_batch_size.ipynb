# %%
MOVE FILE: c:\Users\rashe\Dropbox\1_Work\1a_gitrepoz\time_series\notebooks\1_4Bz.ipynb
{
    "cells": [
        {
            "cell_type": "code",
            "id": "#VSC-ce23e9a0",
            "metadata": {
                "language": "python"
            },
            "source": [
                "split= 0.8",
                "s = '_S8020'",
                "v= 0",
                "epno = 10",
                "e = '_e10'",
                "wz = 30",
                "w = '_wz30'",
                "# bz = 64",
                "# b ='_b64_'",
                "shuffle_buffer_size = 1000",
                "lrno = 0.0008",
                "l = 'l0008'",
                "window_size = wz",
                "look_back = wz",
                "o = 'Adam'"
            ]
        },
        {
            "cell_type": "code",
            "id": "#VSC-0fce6323",
            "metadata": {
                "language": "python"
            },
            "source": [
                "df_rmse_SAL =pd.DataFrame()",
                "df_t_SAL =pd.DataFrame()",
                "df_rmse1_SAL = pd.DataFrame()",
                "df_t1_SAL = pd.DataFrame()",
                "",
                "df_rmse_PH =pd.DataFrame()",
                "df_t_PH =pd.DataFrame()",
                "df_rmse1_PH =pd.DataFrame()",
                "df_t1_PH =pd.DataFrame()",
                "",
                "df_rmse_DO =pd.DataFrame()",
                "df_t_DO =pd.DataFrame()",
                "df_rmse1_DO =pd.DataFrame()",
                "df_t1_DO =pd.DataFrame()",
                "",
                "df_rmse_TEMP =pd.DataFrame()",
                "df_t_TEMP =pd.DataFrame()",
                "df_rmse1_TEMP =pd.DataFrame()",
                "df_t1_TEMP =pd.DataFrame()"
            ]
        },
        {
            "cell_type": "code",
            "id": "#VSC-5d380602",
            "metadata": {
                "language": "python"
            },
            "source": [
                "bz = 16",
                "batch_size = bz",
                "",
                "b ='_b16_'",
                "opt = tf.keras.optimizers.Adam(learning_rate=lrno) #, momentum=0.9)",
                "%run 2.io_Loop_4WQP.ipynb"
            ]
        },
        {
            "cell_type": "code",
            "id": "#VSC-198e350c",
            "metadata": {
                "language": "python"
            },
            "source": [
                "bz = 32",
                "batch_size = bz",
                "",
                "b ='_b32_'",
                "opt = tf.keras.optimizers.Adam(learning_rate=lrno) #, momentum=0.9)",
                "%run 2.io_Loop_4WQP.ipynb"
            ]
        },
        {
            "cell_type": "code",
            "id": "#VSC-56ad6874",
            "metadata": {
                "language": "python"
            },
            "source": [
                "bz = 64",
                "batch_size = bz",
                "",
                "b ='_b64_'",
                "opt = tf.keras.optimizers.Adam(learning_rate=lrno) #, momentum=0.9)",
                "%run 2.io_Loop_4WQP.ipynb"
            ]
        },
        {
            "cell_type": "code",
            "id": "#VSC-9e9b073a",
            "metadata": {
                "language": "python"
            },
            "source": [
                "bz = 128",
                "batch_size = bz",
                "",
                "b ='_b128_'",
                "opt = tf.keras.optimizers.Adam(learning_rate=lrno) #, momentum=0.9)",
                "%run 2.io_Loop_4WQP.ipynb"
            ]
        },
        {
            "cell_type": "code",
            "id": "#VSC-e15995cb",
            "metadata": {
                "language": "python"
            },
            "source": [
                "bz = 256",
                "batch_size = bz",
                "",
                "b ='_b256_'",
                "opt = tf.keras.optimizers.Adam(learning_rate=lrno) #, momentum=0.9)",
                "%run 2.io_Loop_4WQP.ipynb"
            ]
        },
        {
            "cell_type": "code",
            "id": "#VSC-d2125500",
            "metadata": {
                "language": "python"
            },
            "source": [
                "bz = 512",
                "batch_size = bz",
                "",
                "b ='_b512_'",
                "opt = tf.keras.optimizers.Adam(learning_rate=lrno) #, momentum=0.9)",
                "%run 2.io_Loop_4WQP.ipynb"
            ]
        },
        {
            "cell_type": "code",
            "id": "#VSC-f43c0186",
            "metadata": {
                "language": "python"
            },
            "source": [
                "df_rmse1_SAL.to_csv('4.Bz_vs_RMSE/1.SAL.csv')",
                "df_t1_SAL.to_csv('4.Bz_vs_RMSE/1.SAL_t.csv')",
                "",
                "df_rmse1_PH.to_csv('4.Bz_vs_RMSE/2.PH.csv')",
                "df_t1_PH.to_csv('4.Bz_vs_RMSE/2.PH_t.csv')",
                "",
                "df_rmse1_DO.to_csv('4.Bz_vs_RMSE/3.DO.csv')",
                "df_t1_DO.to_csv('4.Bz_vs_RMSE/3.DO_t.csv')",
                "",
                "df_rmse1_TEMP.to_csv('4.Bz_vs_RMSE/4.TEMP.csv')",
                "df_t1_TEMP.to_csv('4.Bz_vs_RMSE/4.TEMP_t.csv')"
            ]
        },
        {
            "cell_type": "code",
            "id": "#VSC-7ae4af56",
            "metadata": {
                "language": "python"
            },
            "source": [
                "import datetime",
                "now = datetime.datetime.now()",
                "print (\"Current date and time : \")",
                "print (now.strftime(\"%Y-%m-%d %H:%M:%S\"))"
            ]
        }
    ]
}

# %%
split= 0.8
s = '_S8020'
v= 0
epno = 10
e = '_e10'
wz = 30
w = '_wz30'
# bz = 64
# b ='_b64_'
shuffle_buffer_size = 1000
lrno = 0.0008
l = 'l0008'
window_size = wz
look_back = wz
o = 'Adam'

# %%
df_rmse_SAL =pd.DataFrame()
df_t_SAL =pd.DataFrame()
df_rmse1_SAL = pd.DataFrame()
df_t1_SAL = pd.DataFrame()

df_rmse_PH =pd.DataFrame()
df_t_PH =pd.DataFrame()
df_rmse1_PH =pd.DataFrame()
df_t1_PH =pd.DataFrame()

df_rmse_DO =pd.DataFrame()
df_t_DO =pd.DataFrame()
df_rmse1_DO =pd.DataFrame()
df_t1_DO =pd.DataFrame()

df_rmse_TEMP =pd.DataFrame()
df_t_TEMP =pd.DataFrame()
df_rmse1_TEMP =pd.DataFrame()
df_t1_TEMP =pd.DataFrame()

# %%
bz = 16
batch_size = bz

b ='_b16_'
opt = tf.keras.optimizers.Adam(learning_rate=lrno) #, momentum=0.9)
# %run 2.io_Loop_4WQP.ipynb

# %%
bz = 32
batch_size = bz

b ='_b32_'
opt = tf.keras.optimizers.Adam(learning_rate=lrno) #, momentum=0.9)
# %run 2.io_Loop_4WQP.ipynb

# %%
bz = 64
batch_size = bz

b ='_b64_'
opt = tf.keras.optimizers.Adam(learning_rate=lrno) #, momentum=0.9)
# %run 2.io_Loop_4WQP.ipynb

# %%
bz = 128
batch_size = bz

b ='_b128_'
opt = tf.keras.optimizers.Adam(learning_rate=lrno) #, momentum=0.9)
# %run 2.io_Loop_4WQP.ipynb

# %%
bz = 256
batch_size = bz

b ='_b256_'
opt = tf.keras.optimizers.Adam(learning_rate=lrno) #, momentum=0.9)
# %run 2.io_Loop_4WQP.ipynb

# %%
bz = 512
batch_size = bz

b ='_b512_'
opt = tf.keras.optimizers.Adam(learning_rate=lrno) #, momentum=0.9)
# %run 2.io_Loop_4WQP.ipynb

# %%
df_rmse1_SAL.to_csv('4.Bz_vs_RMSE/1.SAL.csv')
df_t1_SAL.to_csv('4.Bz_vs_RMSE/1.SAL_t.csv')

df_rmse1_PH.to_csv('4.Bz_vs_RMSE/2.PH.csv')
df_t1_PH.to_csv('4.Bz_vs_RMSE/2.PH_t.csv')

df_rmse1_DO.to_csv('4.Bz_vs_RMSE/3.DO.csv')
df_t1_DO.to_csv('4.Bz_vs_RMSE/3.DO_t.csv')

df_rmse1_TEMP.to_csv('4.Bz_vs_RMSE/4.TEMP.csv')
df_t1_TEMP.to_csv('4.Bz_vs_RMSE/4.TEMP_t.csv')

# %%
import datetime
now = datetime.datetime.now()
print ("Current date and time : ")
print (now.strftime("%Y-%m-%d %H:%M:%S"))
